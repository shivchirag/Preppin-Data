# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import datetime as dt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd_data_base_path = '/content/drive/MyDrive/Preppin Data/Data/'

# %%
swift = pd.read_csv(pd_data_base_path + 'Swift Codes.csv')
transactions = pd.read_csv(pd_data_base_path + 'Transactions.csv')

# %%
swift.head()
# Out:
#             Bank SWIFT code Check Digits
# 0    Lloyds Bank       LOYD           C1
# 1  Barclays Bank       BARC           22
# 2        Halifax       HLFX           22
# 3           HSBC       HBUK           4B
# 4        Natwest       NWBK           2L

# %%
transactions.head()
# Out:
#    Transaction ID  Account Number Sort Code              Bank
# 0            3888        62230725  95-98-82  Data Source Bank
# 1            4746        83172326  42-86-38     Barclays Bank
# 2            5404        34302539  53-28-21     Barclays Bank
# 3            9013        13350031  93-87-71           Natwest
# 4            2535        68745993  57-14-32     Barclays Bank

# %%
df = pd.merge(transactions, swift, on='Bank')
df.head()
# Out:
#    Transaction ID  Account Number Sort Code              Bank SWIFT code  \
# 0            3888        62230725  95-98-82  Data Source Bank       DSBX
# 1            7086        56630552  59-77-44  Data Source Bank       DSBX
# 2            1314        71210735  61-85-79  Data Source Bank       DSBX
# 3            1493        12193988  86-54-42  Data Source Bank       DSBX
# 4            1952        53786334  21-27-54  Data Source Bank       DSBX
#
#   Check Digits
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12

# %%
df['Sort Code'] = df['Sort Code'].apply(lambda x: ''.join(x.split('-')))

# %%
df['Country Code'] = 'GB'

# %%
df['IBAN'] = df['Country Code'].astype('str') + df['Check Digits'].astype('str') + df['SWIFT code'] + df['Sort Code'].astype('str') + df['Account Number'].astype('str')

# %%
df = df[['Transaction ID', 'IBAN']]
df.head()
# Out:
#    Transaction ID                    IBAN
# 0            3888  GB12DSBX95988262230725
# 1            7086  GB12DSBX59774456630552
# 2            1314  GB12DSBX61857971210735
# 3            1493  GB12DSBX86544212193988
# 4            1952  GB12DSBX21275453786334
