# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from datetime import datetime as dt
import math

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd_data_base_path = '/content/drive/MyDrive/Preppin Data/Data/'

# %%
list_of_dfs = []
df = pd.read_csv(pd_data_base_path + 'MOCK_DATA.csv')
df['month'] = 1
list_of_dfs.append(df)
for i in range(1,12):
  df = pd.read_csv(pd_data_base_path + 'MOCK_DATA-' + str(i+1) +'.csv')
  df['month'] = i+1
  list_of_dfs.append(df)

# %%
df = pd.concat(list_of_dfs, ignore_index=True)

# %%
df.month.value_counts()
# Out:
# 1     1000
# 2     1000
# 3     1000
# 4     1000
# 5     1000
# 6     1000
# 7     1000
# 8     1000
# 9     1000
# 10    1000
# 11    1000
# 12    1000
# Name: month, dtype: int64

# %%
df.rename(columns={'Market Cap':'Market Capitalisation'}, inplace=True)

# %%
df = df.dropna(subset=['Market Capitalisation'])

# %%
def purchase_price_categorisation(x):
  if float(x[1:])<24999.99:
    return 'Low'
  elif float(x[1:])<49999.99:
    return 'Medium'
  elif float(x[1:])<74999.99:
    return 'High'
  elif float(x[1:])>=75000:
    return 'Very High'

df['Purchase Price Categorisation'] = df['Purchase Price'].apply(purchase_price_categorisation)

# %%
def market_capitalisation_categorisation(x):
  if x[-1]=='B':
    if float(x[1:-1])<100:
      return 'Large'
    else:
      return 'Huge'
  else:
    if float(x[1:-1])<100:
      return 'Small'
    else:
      return 'Medium'

df['Market Capitalisation Categorisation'] = df['Market Capitalisation'].apply(market_capitalisation_categorisation)

# %%
df['Purchase Price'] = pd.to_numeric(df['Purchase Price'].str.replace('[$,]', '', regex=True)).round(2)

# %%
mask_df = (
    df.sort_values(['month', 'Purchase Price Categorisation', 'Market Capitalisation Categorisation', 'Purchase Price'], ascending=[True, True, True, False])
    .groupby(['month', 'Purchase Price Categorisation', 'Market Capitalisation Categorisation'])
    .cumcount()
    .to_frame(name='Rank')
    .merge(df, left_index=True, right_index=True)
    .reset_index(drop=True)
  )

# %%
mask_df
# Out:
#        Rank   id first_name    last_name Ticker                 Sector  \
# 0         0  966    Artemas     Franzini      A          Capital Goods
# 1         1  425   Bernetta     Garshore    OSK          Capital Goods
# 2         2  715     Jeanne      Ugolini   PLAY      Consumer Services
# 3         3  868   Angelika      Shurman    DOC      Consumer Services
# 4         4   54       Jany       Hancke   CSOD             Technology
# ...     ...  ...        ...          ...    ...                    ...
# 10104    37  386     Godard  Aloshechkin   AZRX                    NaN
# 10105    38  283    Caresse        Pyrke   RELY  Consumer Non-Durables
# 10106    39  560       Bren      Stiller   ELON             Technology
# 10107    40  253       Kiri     Chopping   CTIB       Basic Industries
# 10108    41  612      Nanon      Allenby   PSET                    NaN
#
#        Market                           Stock Name Market Capitalisation  \
# 0        NYSE           Agilent Technologies, Inc.               $19.12B
# 1        NYSE                  Oshkosh Corporation                $5.07B
# 2      NASDAQ  Dave & Buster's Entertainment, Inc.                $2.84B
# 3        NYSE              Physicians Realty Trust                $3.26B
# 4      NASDAQ           Cornerstone OnDemand, Inc.                $2.09B
# ...       ...                                  ...                   ...
# 10104  NASDAQ               AzurRx BioPharma, Inc.               $38.27M
# 10105  NASDAQ                 Real Industry, Inc.                $90.88M
# 10106  NASDAQ                  Echelon Corporation                $24.7M
# 10107  NASDAQ           CTI Industries Corporation               $21.03M
# 10108  NASDAQ    Principal Price Setters Index ETF                $7.24M
#
#        Purchase Price  month Purchase Price Categorisation  \
# 0            74995.16      1                          High
# 1            74935.82      1                          High
# 2            74621.72      1                          High
# 3            74155.03      1                          High
# 4            74079.42      1                          High
# ...               ...    ...                           ...
# 10104        78218.19     12                     Very High
# 10105        78113.35     12                     Very High
# 10106        77270.32     12                     Very High
# 10107        76885.36     12                     Very High
# 10108        75048.62     12                     Very High
#
#       Market Capitalisation Categorisation
# 0                                    Large
# 1                                    Large
# 2                                    Large
# 3                                    Large
# 4                                    Large
# ...                                    ...
# 10104                                Small
# 10105                                Small
# 10106                                Small
# 10107                                Small
# 10108                                Small
#
# [10109 rows x 13 columns]

# %%
df = mask_df[mask_df['Rank']<5]
df['Rank'] = df['Rank'] + 1
columns = ['Market Capitalisation Categorisation', 'Purchase Price Categorisation', 'month', 'Ticker', 'Sector', 'Market', 'Stock Name', 'Market Capitalisation', 'Purchase Price', 'Rank']
df = df[columns]

# %%
df.head()
# Out:
#   Market Capitalisation Categorisation Purchase Price Categorisation  month  \
# 0                                Large                          High      1
# 1                                Large                          High      1
# 2                                Large                          High      1
# 3                                Large                          High      1
# 4                                Large                          High      1
#
#   Ticker             Sector  Market                           Stock Name  \
# 0      A      Capital Goods    NYSE           Agilent Technologies, Inc.
# 1    OSK      Capital Goods    NYSE                  Oshkosh Corporation
# 2   PLAY  Consumer Services  NASDAQ  Dave & Buster's Entertainment, Inc.
# 3    DOC  Consumer Services    NYSE              Physicians Realty Trust
# 4   CSOD         Technology  NASDAQ           Cornerstone OnDemand, Inc.
#
#   Market Capitalisation  Purchase Price  Rank
# 0               $19.12B        74995.16     1
# 1                $5.07B        74935.82     2
# 2                $2.84B        74621.72     3
# 3                $3.26B        74155.03     4
# 4                $2.09B        74079.42     5

# %%
df.shape
# Out:
# (831, 10)
